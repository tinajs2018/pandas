# %%
import pandas as pd

# %%
#creating a data frame
import pandas as pd
data=pd.DataFrame({'student':['jane','kelly','jessica'],'grade':[23,67,89] ,'height':[34,67,89]},index=['ecomics','computer','stati'] )
data
# Out:
#           student  grade  height
# ecomics      jane     23      34
# computer    kelly     67      67
# stati     jessica     89      89

# %%
#creating a series which a list of items
pd.Series([34,56,89,45,23],index=['micah','mary','eunice','molly','ken'],name='points earned')
# Out:
# micah     34
# mary      56
# eunice    89
# molly     45
# ken       23
# Name: points earned, dtype: int64

# %%
df=pd.read_csv("rocksamples.csv")
df.head()
# Out:
#       ID   Mission    Type   Subtype  Weight (g)  Pristine (%)
# 0  10001  Apollo11    Soil  Unsieved       125.8         88.36
# 1  10002  Apollo11    Soil  Unsieved      5629.0         93.73
# 2  10003  Apollo11  Basalt  Ilmenite       213.0         65.56
# 3  10004  Apollo11    Core  Unsieved        44.8         71.76
# 4  10005  Apollo11    Core  Unsieved        53.4         40.31

# %%
#seeing how large that data is
df.shape
#meaning it has 2229 row and 6 columns
# Out:
# (2229, 6)

# %%
#examine the content of the dataframe 
df.head()
# Out:
#       ID   Mission    Type   Subtype  Weight (g)  Pristine (%)
# 0  10001  Apollo11    Soil  Unsieved       125.8         88.36
# 1  10002  Apollo11    Soil  Unsieved      5629.0         93.73
# 2  10003  Apollo11  Basalt  Ilmenite       213.0         65.56
# 3  10004  Apollo11    Core  Unsieved        44.8         71.76
# 4  10005  Apollo11    Core  Unsieved        53.4         40.31

# %%
df=pd.read_csv("rocksamples.csv", index_col=0)
df.head()
#index_col removes the inbult indexing that as been created bypandas
# Out:
#         Mission    Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11    Soil  Unsieved       125.8         88.36
# 10002  Apollo11    Soil  Unsieved      5629.0         93.73
# 10003  Apollo11  Basalt  Ilmenite       213.0         65.56
# 10004  Apollo11    Core  Unsieved        44.8         71.76
# 10005  Apollo11    Core  Unsieved        53.4         40.31

# %%
df.Mission
# Out:
# ID
# 10001    Apollo11
# 10002    Apollo11
# 10003    Apollo11
# 10004    Apollo11
# 10005    Apollo11
#            ...
# 79528    Apollo17
# 79529    Apollo17
# 79535    Apollo17
# 79536    Apollo17
# 79537    Apollo17
# Name: Mission, Length: 2229, dtype: object

# %%
#to drill down to a specific  item we use indexing
df['Type'][10002]
# Out:
# 'Soil'

# %%
#index-based selection that is the indexing based on the  numerical position pf the data
df.iloc[0]
#this is selecting the first row of the dataframe
# Out:
# Mission         Apollo11
# Type                Soil
# Subtype         Unsieved
# Weight (g)         125.8
# Pristine (%)       88.36
# Name: 10001, dtype: object

# %%
#to get row with clumns you can use
df.iloc[:2,0]
# Out:
# ID
# 10001    Apollo11
# 10002    Apollo11
# Name: Mission, dtype: object

# %%
df.iloc[-2:]
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 79536  Apollo17  Breccia  Regolith        1.66         100.0
# 79537  Apollo17  Breccia  Regolith        1.05         100.0

# %%
#label based selection :here is is the index of the data matters not the position
df.loc[79536,'Mission']
# Out:
# 'Apollo17'

# %%
df.set_index('Mission').head()
#This is useful if you can comeup withthe index which is better than the current one
# Out:
#             Type   Subtype  Weight (g)  Pristine (%)
# Mission
# Apollo11    Soil  Unsieved       125.8         88.36
# Apollo11    Soil  Unsieved      5629.0         93.73
# Apollo11  Basalt  Ilmenite       213.0         65.56
# Apollo11    Core  Unsieved        44.8         71.76
# Apollo11    Core  Unsieved        53.4         40.31

# %%
df.Mission=='Apollo11'
#conditinal selection of the data
# Out:
# ID
# 10001     True
# 10002     True
# 10003     True
# 10004     True
# 10005     True
#          ...
# 79528    False
# 79529    False
# 79535    False
# 79536    False
# 79537    False
# Name: Mission, Length: 2229, dtype: bool

# %%
#selcting relevant data 
df.loc[df.Mission=='Apollo11']
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11     Soil  Unsieved      125.80         88.36
# 10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 10004  Apollo11     Core  Unsieved       44.80         71.76
# 10005  Apollo11     Core  Unsieved       53.40         40.31
# ...         ...      ...       ...         ...           ...
# 10090  Apollo11     Soil  Unsieved       12.00          0.00
# 10091  Apollo11  Breccia  Regolith        0.00          0.00
# 10092  Apollo11   Basalt  Ilmenite       46.00         83.92
# 10093  Apollo11  Breccia  Regolith       25.85         93.11
# 10094  Apollo11  Breccia  Regolith       30.25         92.64
#
# [67 rows x 5 columns]

# %%
#selecting specifc data one desires in the dataframe
core=df.loc[df.Type=='Core']
core
# Out:
#         Mission  Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10004  Apollo11  Core  Unsieved       44.80         71.76
# 10005  Apollo11  Core  Unsieved       53.40         40.31
# 12025  Apollo12  Core  Unsieved       56.10        163.41
# 12026  Apollo12  Core  Unsieved      101.40         53.28
# 12027  Apollo12  Core  Unsieved       80.00         48.50
# 12028  Apollo12  Core  Unsieved      189.60         27.56
# 14210  Apollo14  Core  Unsieved      169.70         71.60
# 14211  Apollo14  Core  Unsieved       39.50         77.75
# 14220  Apollo14  Core  Unsieved       80.70         62.80
# 14230  Apollo14  Core  Unsieved       76.70         40.20
# 14411  Apollo14  Core  Unsieved        5.53          1.81
# 14414  Apollo14  Core  Unsieved        5.46          1.83
# 15001  Apollo15  Core  Unsieved      232.80         54.58
# 15002  Apollo15  Core  Unsieved      210.10         64.13
# 15003  Apollo15  Core  Unsieved      223.00         68.38
# ...

# %%
df.loc[(df.Type=='Core')&(df.Mission=='Apollo17')]
# Out:
#         Mission  Type   Subtype  Weight (g)  Pristine (%)
# ID
# 70001  Apollo17  Core  Unsieved       29.78         48.17
# 70002  Apollo17  Core  Unsieved      207.80         73.85
# 70003  Apollo17  Core  Unsieved      237.80         76.04
# 70004  Apollo17  Core  Unsieved      238.80         74.64
# 70005  Apollo17  Core  Unsieved      240.70         77.23
# 70006  Apollo17  Core  Unsieved      234.20         73.96
# 70007  Apollo17  Core  Unsieved      179.40         74.56
# 70008  Apollo17  Core  Unsieved      255.80         72.85
# 70009  Apollo17  Core  Unsieved      143.30         71.58
# 70012  Apollo17  Core  Unsieved      485.00        100.00
# 73001  Apollo17  Core  Unsieved      809.00        100.00
# 73002  Apollo17  Core  Unsieved      429.70        100.00
# 74001  Apollo17  Core  Unsieved     1072.00         74.72
# 74002  Apollo17  Core  Unsieved      909.60         74.55
# 76001  Apollo17  Core  Unsieved      711.60         76.86
# ...

# %%
df.loc[df.Mission.isin(['Apollo17','Apollo16'])]
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 60001  Apollo16     Core  unsieved       30.10         45.49
# 60002  Apollo16     Core  unsieved      211.80         74.02
# 60003  Apollo16     Core  unsieved      215.90         74.88
# 60004  Apollo16     Core  unsieved      202.70         72.86
# 60005  Apollo16     Core  unsieved       77.30         95.96
# ...         ...      ...       ...         ...           ...
# 79528  Apollo17  Breccia  Regolith        2.38        100.00
# 79529  Apollo17  Breccia  Regolith        1.84        100.00
# 79535  Apollo17  Breccia  Regolith        1.69        100.00
# 79536  Apollo17  Breccia  Regolith        1.66        100.00
# 79537  Apollo17  Breccia  Regolith        1.05        100.00
#
# [1523 rows x 5 columns]

# %%
df.loc[df.Type.isin(['Soil','Core'])]
# Out:
#         Mission  Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11  Soil  Unsieved      125.80         88.36
# 10002  Apollo11  Soil  Unsieved     5629.00         93.73
# 10004  Apollo11  Core  Unsieved       44.80         71.76
# 10005  Apollo11  Core  Unsieved       53.40         40.31
# 10008  Apollo11  Soil  Unsieved       89.00          5.75
# ...         ...   ...       ...         ...           ...
# 79510  Apollo17  Soil  Unsieved      107.60         98.42
# 79511  Apollo17  Soil      <1mm      179.20         95.88
# 79512  Apollo17  Soil     1-2mm       11.32         93.36
# 79513  Apollo17  Soil     2-4mm        9.94         89.94
# 79514  Apollo17  Soil    4-10mm       12.24         97.47
#
# [869 rows x 5 columns]

# %%
df.loc[df.Type.notnull()]
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11     Soil  Unsieved      125.80         88.36
# 10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 10004  Apollo11     Core  Unsieved       44.80         71.76
# 10005  Apollo11     Core  Unsieved       53.40         40.31
# ...         ...      ...       ...         ...           ...
# 79528  Apollo17  Breccia  Regolith        2.38        100.00
# 79529  Apollo17  Breccia  Regolith        1.84        100.00
# 79535  Apollo17  Breccia  Regolith        1.69        100.00
# 79536  Apollo17  Breccia  Regolith        1.66        100.00
# 79537  Apollo17  Breccia  Regolith        1.05        100.00
#
# [2229 rows x 5 columns]

# %%
df.describe()
# Out:
#          Weight (g)  Pristine (%)
# count   2229.000000   2229.000000
# mean     168.253024     84.512764
# std      637.286458     22.057299
# min        0.000000      0.000000
# 25%        3.000000     80.010000
# 50%       10.200000     92.300000
# 75%       93.490000     98.140000
# max    11729.000000    180.000000

# %%
#fro a given column
df['Pristine (%)'].describe()
# Out:
# count    2229.000000
# mean       84.512764
# std        22.057299
# min         0.000000
# 25%        80.010000
# 50%        92.300000
# 75%        98.140000
# max       180.000000
# Name: Pristine (%), dtype: float64

# %%
df['Mission'].describe()
# Out:
# count         2229
# unique           6
# top       Apollo16
# freq           767
# Name: Mission, dtype: object

# %%
#check for those unique values
df['Mission'].unique ()
# Out:
# array(['Apollo11', 'Apollo12', 'Apollo14', 'Apollo15', 'Apollo16',
#        'Apollo17'], dtype=object)

# %%
df['Type'].unique()
# Out:
# array(['Soil', 'Basalt', 'Core', 'Breccia', 'Special', 'Crustal'],
#       dtype=object)

# %%
#to see how often those unique item apper in the dataset
df['Mission'].value_counts()
#so here in short applolo 16 went to the most space missions
# Out:
# Apollo16    767
# Apollo17    756
# Apollo15    364
# Apollo14    207
# Apollo12     68
# Apollo11     67
# Name: Mission, dtype: int64

# %%
df['Type'].value_counts()
#so here the  material which often come out the space was this Breccia    959
# Out:
# Breccia    959
# Soil       813
# Basalt     351
# Core        56
# Crustal     46
# Special      4
# Name: Type, dtype: int64

# %%
#unique items
df['Subtype'].unique()
# Out:
# array(['Unsieved', 'Ilmenite', 'Regolith', 'Cristobalite', 'Olivine',
#        'Pigeonite', 'Fragmental', nan, 'Feldspathic', 'Unclassified',
#        '2-4mm', '1-2mm', '<1mm', '4-10mm', '>10mm', 'ImpactMelt', 'KREEP',
#        'Glass', 'Agglomerate', 'Unstudied', 'Cataclastic', 'Clod',
#        'Anorthosite', 'unsieved', 'Plagioclase', 'fragmental',
#        'unstudied', 'notstudied', 'Cataclasite', 'Troctolite', 'Norite',
#        'Pristine'], dtype=object)

# %%
df['Subtype'].value_counts()
#showing which subgroup was frequent from the moon and the least frequent from the moon
# Out:
# ImpactMelt      393
# Unsieved        271
# Regolith        248
# Fragmental      208
# Ilmenite        184
# <1mm            147
# 1-2mm           145
# 2-4mm           145
# 4-10mm          145
# Olivine         115
# Anorthosite      41
# Pigeonite        37
# Unclassified     24
# fragmental       21
# unsieved         17
# Clod             17
# Cataclasite      16
# unstudied        10
# Agglomerate      10
# Feldspathic       8
# Glass             7
# Norite            4
# Cataclastic       3
# KREEP             3
# notstudied        1
# Unstudied         1
# Cristobalite      1
# Pristine          1
# Plagioclase       1
# Troctolite        1
# >10mm             1
# Name: Subtype, dtype: int64

# %%
weight=df['Weight (g)'].mean()
df['Weight (g)']-weight
# Out:
# ID
# 10001     -42.453024
# 10002    5460.746976
# 10003      44.746976
# 10004    -123.453024
# 10005    -114.853024
#             ...
# 79528    -165.873024
# 79529    -166.413024
# 79535    -166.563024
# 79536    -166.593024
# 79537    -167.203024
# Name: Weight (g), Length: 2229, dtype: float64

# %%
df.groupby('Mission').Mission.count()
# Out:
# Mission
# Apollo11     67
# Apollo12     68
# Apollo14    207
# Apollo15    364
# Apollo16    767
# Apollo17    756
# Name: Mission, dtype: int64

# %%
df.groupby('Type').Type .count()
# Out:
# Type
# Basalt     351
# Breccia    959
# Core        56
# Crustal     46
# Soil       813
# Special      4
# Name: Type, dtype: int64

# %%
df.groupby('Type'). Mission .min()
#shows which mission had the leat items from the space
# Out:
# Type
# Basalt     Apollo11
# Breccia    Apollo11
# Core       Apollo11
# Crustal    Apollo15
# Soil       Apollo11
# Special    Apollo12
# Name: Mission, dtype: object

# %%
df.groupby(['Type','Subtype']). Mission .max()
#this iinnloves grouping the data into it type and it subtypes
#showing which mission arrive from the space with the most materials
#another intesting isight is that only apollop 16 and 17 were able to return with the core from the moon
# Out:
# Type     Subtype
# Basalt   Cristobalite    Apollo11
#          Feldspathic     Apollo14
#          Ilmenite        Apollo17
#          KREEP           Apollo15
#          Olivine         Apollo15
#          Pigeonite       Apollo15
#          Plagioclase     Apollo16
#          Unclassified    Apollo17
# Breccia  Agglomerate     Apollo15
#          Anorthosite     Apollo16
#          Clod            Apollo15
#          Feldspathic     Apollo14
#          Fragmental      Apollo17
#          Glass           Apollo16
#          ImpactMelt      Apollo17
#          Regolith        Apollo17
#          Unclassified    Apollo17
#          Unstudied       Apollo15
#          fragmental      Apollo16
#          notstudied      Apollo16
#          unstudied       Apollo16
# Core     Unsieved        Apollo17
#          unsieved        Apollo16
# Crustal  Anorthosite     Apollo16
#          Cataclasite     Apollo17
#          Cataclastic     Apollo15
#          Fragmental      Apollo16
# ...

# %%
df.groupby(['Mission','Weight (g)','Pristine (%)']).agg([max,min,len,])
#take out groupby is very powerful in analysis of data
# Out:
#                                      Type                  Subtype  \
#                                       max      min len         max
# Mission  Weight (g) Pristine (%)
# Apollo11 0.00       0.00             Soil  Breccia   2    Unsieved
#          0.40       35.44            Soil     Soil   1    Unsieved
#          1.12       0.00             Soil     Soil   1    Unsieved
#          1.81       96.69         Breccia  Breccia   1    Regolith
#          2.70       90.74          Basalt   Basalt   1    Ilmenite
# ...                                   ...      ...  ..         ...
# Apollo17 3640.00    90.86         Breccia  Breccia   1  Fragmental
#          5727.00    92.03         Breccia  Breccia   1  ImpactMelt
#          5765.00    78.21          Basalt   Basalt   1    Ilmenite
#          6412.00    95.43         Breccia  Breccia   1  ImpactMelt
#          8110.00    90.68          Basalt   Basalt   1    Ilmenite
#
#
#                                          min len
# ...

# %%
df['Mission'].sort_index(ascending=False)
# Out:
# ID
# 79537    Apollo17
# 79536    Apollo17
# 79535    Apollo17
# 79529    Apollo17
# 79528    Apollo17
#            ...
# 10005    Apollo11
# 10004    Apollo11
# 10003    Apollo11
# 10002    Apollo11
# 10001    Apollo11
# Name: Mission, Length: 2229, dtype: object

# %%
df.sort_values(by=['Mission','Type'],ascending=False)
# Out:
#         Mission    Type   Subtype  Weight (g)  Pristine (%)
# ID
# 70010  Apollo17    Soil  Unsieved        3.92          0.00
# 70011  Apollo17    Soil  Unsieved      440.70         83.62
# 70030  Apollo17    Soil  Unsieved       33.92          0.00
# 70050  Apollo17    Soil  Unsieved      573.40         87.11
# 70051  Apollo17    Soil      <1mm     1438.00         80.45
# ...         ...     ...       ...         ...           ...
# 10062  Apollo11  Basalt  Ilmenite       78.50         35.07
# 10069  Apollo11  Basalt  Ilmenite      119.50         61.09
# 10071  Apollo11  Basalt  Ilmenite      189.50         68.02
# 10072  Apollo11  Basalt  Ilmenite      447.00         15.22
# 10092  Apollo11  Basalt  Ilmenite       46.00         83.92
#
# [2229 rows x 5 columns]

# %%
df.Mission.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Mission          object
# Type             object
# Subtype          object
# Weight (g)      float64
# Pristine (%)    float64
# dtype: object

# %%
#changing from one data type to another
df['Weight (g)'].astype('int64').head()
# Out:
# ID
# 10001     125
# 10002    5629
# 10003     213
# 10004      44
# 10005      53
# Name: Weight (g), dtype: int64

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
#to select  Nan number which stands for not a number
# df[pd.isnull(df.Mission)]
df[pd.notnull(df.Mission)]
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11     Soil  Unsieved      125.80         88.36
# 10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 10004  Apollo11     Core  Unsieved       44.80         71.76
# 10005  Apollo11     Core  Unsieved       53.40         40.31
# ...         ...      ...       ...         ...           ...
# 79528  Apollo17  Breccia  Regolith        2.38        100.00
# 79529  Apollo17  Breccia  Regolith        1.84        100.00
# 79535  Apollo17  Breccia  Regolith        1.69        100.00
# 79536  Apollo17  Breccia  Regolith        1.66        100.00
# 79537  Apollo17  Breccia  Regolith        1.05        100.00
#
# [2229 rows x 5 columns]

# %%
#filling the null value with the unknown value
df.fillna("unknown")
# Out:
#         Mission     Type   Subtype  Weight (g)  Pristine (%)
# ID
# 10001  Apollo11     Soil  Unsieved      125.80         88.36
# 10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 10004  Apollo11     Core  Unsieved       44.80         71.76
# 10005  Apollo11     Core  Unsieved       53.40         40.31
# ...         ...      ...       ...         ...           ...
# 79528  Apollo17  Breccia  Regolith        2.38        100.00
# 79529  Apollo17  Breccia  Regolith        1.84        100.00
# 79535  Apollo17  Breccia  Regolith        1.69        100.00
# 79536  Apollo17  Breccia  Regolith        1.66        100.00
# 79537  Apollo17  Breccia  Regolith        1.05        100.00
#
# [2229 rows x 5 columns]
